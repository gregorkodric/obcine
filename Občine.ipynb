# %% [markdown]
# # Občine
#
#
# Analiza podatkov o občinah.
#
# ## Župani
#
# Župani se delijo na:
# - priljubljene in
# - nepriljubljene

# %%
import pandas as pd

seznam_obcin = pd.read_csv('csv-datoteke/index.csv')

# %%
seznam_obcin
# Out:
#                                    ime                    zupan  \
# 0                           Ajdovščina           Tadej Beočanin
# 1                              Ankaran          Gregor Strmčnik
# 2                                Apače            Franc Pižmoht
# 3                             Benedikt             Milan Gumzar
# 4                    Bistrica ob Sotli          Franjo Debeljak
# 5                                 Bled             Janez Fajfar
# 6                                Bloke               Jože Doles
# 7                               Bohinj             Franc Kramar
# 8                            Borovnica             Bojan Čebela
# 9                                Bovec            Valter Mlekuž
# 10                           Braslovče      Branimir Strojanšek
# 11                                Brda              Franc Muzič
# 12                             Brežice               Ivan Molan
# 13                           Brezovica             Metod Ropret
# ...
